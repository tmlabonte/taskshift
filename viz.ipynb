# %%
import os.path as osp
from PIL import Image

# %%
fname = "risk_sgn_e1_spiked.png"
display(Image.open(osp.join("out", fname)))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3260x2705>
